# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ds = AMReXDataset("plt00000")
# Out:
# yt : [INFO     ] 2017-08-16 16:49:15,563 Parameters: current_time              = 0.0
# yt : [INFO     ] 2017-08-16 16:49:15,563 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2017-08-16 16:49:15,564 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-08-16 16:49:15,564 Parameters: domain_right_edge         = [ 1.  1.  1.]

# %%
direction = 0
sl = yt.ProjectionPlot(ds, direction, 'cost')
sl.annotate_grids()
sl.annotate_particles(ds.domain_width[direction])
sl
# Out:
# yt : [INFO     ] 2017-08-16 16:49:16,626 Projection completed
# yt : [INFO     ] 2017-08-16 16:49:16,635 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:49:16,636 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:49:16,637 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:49:16,638 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:49:16,642 Making a fixed resolution buffer of (('boxlib', 'cost')) 800 by 800
# /home/atmyers/yt-conda/src/yt-git/yt/units/yt_array.py:1062: RuntimeWarning: invalid value encountered in divide
#   return super(YTArray, self).__div__(ro)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
67837 + 45272
# Out:
# 113109

# %%
48643
# Out:
# 48643

# %%
113109 / 2.
# Out:
# 56554.5

# %%
[(g.id, g['cost'].sum(), g['particle_position_x'].size) for g in ds.index.grids]
# Out:
# [(0, 17326.0 dimensionless, 17326),
#  (1, 17127.0 dimensionless, 17127),
#  (2, 17398.0 dimensionless, 17398),
#  (3, 16895.0 dimensionless, 16895),
#  (4, 17153.0 dimensionless, 17153),
#  (5, 17059.0 dimensionless, 17059),
#  (6, 16996.0 dimensionless, 16996),
#  (7, 16886.0 dimensionless, 16886),
#  (8, 17134.0 dimensionless, 17134),
#  (9, 17033.0 dimensionless, 17033),
#  (10, 17340.0 dimensionless, 17340),
#  (11, 16777.0 dimensionless, 16777),
#  (12, 17518.0 dimensionless, 17518),
#  (13, 16853.0 dimensionless, 16853),
#  (14, 17007.0 dimensionless, 17007),
#  (15, 16879.0 dimensionless, 16879)]
