# %%
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ds = AMReXDataset("plt00000")
# Out:
# yt : [INFO     ] 2017-08-16 16:22:56,530 Parameters: current_time              = 0.0
# yt : [INFO     ] 2017-08-16 16:22:56,531 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2017-08-16 16:22:56,531 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-08-16 16:22:56,532 Parameters: domain_right_edge         = [ 1.  1.  1.]

# %%
direction = 0
sl = yt.ProjectionPlot(ds, direction, 'cost')
sl.annotate_grids(draw_ids=True)
sl.annotate_particles(ds.domain_width[direction])
sl
# Out:
# yt : [INFO     ] 2017-08-16 16:22:57,592 Projection completed
# yt : [INFO     ] 2017-08-16 16:22:57,601 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:22:57,601 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:22:57,603 xlim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:22:57,603 ylim = 0.000000 1.000000
# yt : [INFO     ] 2017-08-16 16:22:57,608 Making a fixed resolution buffer of (('boxlib', 'cost')) 800 by 800
# /home/atmyers/yt-conda/src/yt-git/yt/units/yt_array.py:1062: RuntimeWarning: invalid value encountered in divide
#   return super(YTArray, self).__div__(ro)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
67837 + 45272
# Out:
# 113109

# %%
48643
# Out:
# 48643

# %%
113109 / 2.
# Out:
# 56554.5

# %%
[(g.id, g['cost'].sum(), g['particle_position_x'].size) for g in ds.index.grids]
# Out:
# [(0, 15130.0 dimensionless, 15130),
#  (1, 14885.0 dimensionless, 14885),
#  (2, 15832.0 dimensionless, 15832),
#  (3, 14165.0 dimensionless, 14165),
#  (4, 19608.0 dimensionless, 19608),
#  (5, 6951.0 dimensionless, 6951),
#  (6, 13845.0 dimensionless, 13845),
#  (7, 12693.0 dimensionless, 12693)]
