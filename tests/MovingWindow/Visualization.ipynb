# %%
import yt

# %%
cd tmp
# Out:
# /home/atmyers/warpx_directory/warpx/tests/MovingWindow/tmp

# %%
ds = yt.load("plt00000")
all_data_level_0 = ds.covering_grid(level=0, 
                    left_edge=ds.domain_left_edge, dims=ds.domain_dimensions)
# Out:
# yt : [INFO     ] 2017-01-11 14:45:32,470 Parameters: current_time              = 0.0
# yt : [INFO     ] 2017-01-11 14:45:32,472 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2017-01-11 14:45:32,473 Parameters: domain_left_edge          = [ -2.00000000e-05  -2.00000000e-05  -2.00000000e-05]
# yt : [INFO     ] 2017-01-11 14:45:32,475 Parameters: domain_right_edge         = [  2.00000000e-05   2.00000000e-05   2.00000000e-05]

# %%
sl = yt.SlicePlot(ds, 'z', 'E')
sl.annotate_grids()
# Out:
# yt : [INFO     ] 2017-01-11 14:45:32,742 xlim = -0.000020 0.000020
# yt : [INFO     ] 2017-01-11 14:45:32,743 ylim = -0.000020 0.000020
# yt : [INFO     ] 2017-01-11 14:45:32,745 xlim = -0.000020 0.000020
# yt : [INFO     ] 2017-01-11 14:45:32,745 ylim = -0.000020 0.000020
# yt : [INFO     ] 2017-01-11 14:45:32,752 Making a fixed resolution buffer of (('boxlib', 'E')) 800 by 800
# yt : [WARNING  ] 2017-01-11 14:45:32,787 Plot image for field ('boxlib', 'E') has both positive and negative values. Min = -0.000020, Max = 0.000020.
# yt : [WARNING  ] 2017-01-11 14:45:32,788 Switching to symlog colorbar scaling unless linear scaling is specified later
# /home/hepburn/users/atmyers/yt-conda/src/yt-hg/yt/units/yt_array.py:990: RuntimeWarning: invalid value encountered in true_divide
#   return super(YTArray, self).__truediv__(ro)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
