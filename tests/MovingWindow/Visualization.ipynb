# %%
import yt
import glob

# %%
yt.funcs.mylog.setLevel(50)

# %%
fn_list = glob.glob('plt?????')
fn_list.sort()

# %%
for fn in fn_list:
    ds = yt.load(fn)
    print(ds.domain_left_edge, ds.domain_right_edge)
    all_data_level_0 = ds.covering_grid(level=0, 
                        left_edge=ds.domain_left_edge, dims=ds.domain_dimensions)
    sl = yt.SlicePlot(ds, 'z', 'E')
    sl.show()
# Out:
# [ -2.00000000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.00000000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -2.00000000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.00000000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.93750000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.06250000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.93750000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.06250000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.87500000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.12500000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.87500000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.12500000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.81250000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.18750000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.75000000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.25000000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.75000000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.25000000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# [ -1.68750000e-05  -2.00000000e-05  -2.00000000e-05] code_length [  2.31250000e-05   2.00000000e-05   2.00000000e-05] code_length
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
