# %%
# Import statements
import yt ; yt.funcs.mylog.setLevel(50)
import numpy as np
import scipy.constants as scc
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
ds = yt.load( './old_diags/plt00001' ) # Create a dataset object
sl = yt.SlicePlot(ds, 2, 'jx', aspect=.4) # Create a sliceplot object
sl.annotate_grids() # Show grids
sl.show() # Show the plot
# Out:
# /Users/mthevenet/anaconda3/lib/python3.7/site-packages/yt/units/yt_array.py:1394: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds = yt.load( './new_diags/plt00001' ) # Create a dataset object
sl = yt.SlicePlot(ds, 2, 'jx', aspect=.4) # Create a sliceplot object
sl.annotate_grids() # Show grids
sl.show() # Show the plot
# Out:
# /Users/mthevenet/anaconda3/lib/python3.7/site-packages/yt/units/yt_array.py:1394: RuntimeWarning: invalid value encountered in true_divide
#   out=out, **kwargs)
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
